# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# <b>Привет!</b>
#
# Меня зовут Сороколетов Илья и я буду проверять твой проект.
#
# Предлагаю общаться на «**ты**», но если тебе будет комфортнее общаться на «**вы**», то сообщи об этом в комментариях)
#
#
# Для твоего удобства, я буду выделять свои комментарии следующим образом:
#
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b> Самые важные замечания. Они указывают на ключевые моменты, которые влияют на конечный результат проекта. </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b> Советы или замечания, которые помогут сделать твою работу лучше, но необязательны к выполнению.
#
# </div>
#
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b> Так я выделяю все остальные комментарии.</div>
#
#
# Пометками <b>v1-v2-v3-...</b> я буду отмечать версию проверки. Так ты сможешь быстро найти мои новые комментарии.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения, например вот так:
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# </div>
#
# <b>Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии.</b> Если ты оставляешь свои комментарии, то делай это под моими, чтобы сообщения были расположены в хронологическом порядке. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#
# Перед отправкой работы я рекомендую нажимать Kernel -> Restart & Run All. Это перезапустит ядро и по очереди выполнит все ячейки. Так ты сможешь проверить, что всё работает корректно. Кнопка Kernel находится в панели сверху
#
# Обязательно задавай вопросы если они возникнут, а я перехожу к проверке)
#
# P.S. На всякий случай, я оставлю пустой шаблон для твоих комментариев ниже. Кликни два раза на мой комментарий, скопируй последние четыре строчки кода и вставляй их в пустую ячейку там, где ты хочешь оставить комментарий. Не забудь только перед этим сменить тип ячейки на Markdown. Быстро это можно сделать так: кликнуть на ячейку - нажать ESC - нажать M.
#
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Удали этот текст и вместо него напиши свой комментарий 🙂
# </div>

# %% [markdown]
# ## **Описание проекта: оценка рисков невозврата кредита**
#
# В вашем распоряжении данные клиентов банка «Скрудж», которые планируют взять кредит. Вам необходимо выяснить, что из имеющихся данных влияет на своевременное погашение кредита и каким именно образом.
#
# Исследование поможет в создании модели кредитного скоринга — системы для оценки способности потенциального заёмщика погасить свой кредит.
#
# По каждому клиенту есть информация о его семейном положении, образовании, доходе и другие данные. Вам предстоит подготовить данные к анализу и исследовать их, в процессе отвечая на вопросы.
#
# ### Описание данных
#
# - `children` — количество детей в семье;
# - `days_employed` — сколько дней работает клиент;
# - `dob_years` — возраст клиента;
# - `education` — уровень образования клиента;
# - `education_id` — идентификатор образования клиента;
# - `family_status` — семейное положение клиента;
# - `family_status_id` — идентификатор семейного положения клиента;
# - `gender` — пол клиента;
# - `income_type` — тип дохода клиента;
# - `debt` — был ли у клиента когда-либо просрочен платёж по кредиту;
# - `total_income` — ежемесячный доход;
# - `purpose` — причина оформления кредита.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Обрати внимание, что перед проектом расположено краткое описание задачи. Его важно добавлять перед каждым проектом (если его нет изначально). Это поможет тебе быстро вспомнить о чем проект, если спустя время ты решишь к нему вернуться)
# </div>

# %% [markdown]
# ## Шаг 1. Откройте файл с данными и изучите общую информацию
#
# 1. Загрузите датасет.
# 2. Сделайте копию датасета.
# 3. Изучите типы данных и определите, соответствуют ли они содержимому.
# 4. Напишите вывод.

# %% [markdown]
# Импортируем все необходимые библиотеки и датасет для работы

# %%
# Импортируйте библиотеки для работы
# с таблицами и графиками
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Молодец, что импортируешь все библиотеки отдельно в первой ячейке. Это правило хорошего тона, которое позволит твоим коллегам сразу увидеть все необходимые библиотеки для работы с твоим файлом.
# </div>

# %%
# Загрузите датасет в переменную df_raw или другую по вашему выбору.
# Он доступен по адресу <https://code.s3.yandex.net/datasets/credit_scoring_eng.csv>
# а при работе на платформе по адресу /datasets/credit_scoring_eng.csv

df_raw = pd.read_csv('https://code.s3.yandex.net/datasets/credit_scoring_eng.csv')

# %%
# При помощи метода .copy() скопируйте датасет
# для работы с ним в переменную df или другую

df = df_raw.copy()

# %%
# Изучите общую информацию о датасете

#При помощи метода .info() выведем все типы данных по столбцам датафрейма
df.info()

#Выведем первые пять строк датафрейма при помощи метода .head()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB
#    children  days_employed  dob_years            education  education_id  \
# ...

# %% [markdown]
# Проанализируем информацию:
#
#
# *   Данные содержат 21525 строк и 11 столбцов.
# *   Названия меток строк соответствуют спецификации данных.
# *   Столбцы days_employed и total_income содержат пропущенные значения в разном количестве.
# *   Некоторые столбцы могут иметь неоптимальный тип данных, например days_employed и total_income имеют тип данных float64. На мой взгляд, данные после запятой являются избыточной, поэтому можно заменить тип данных в этих столбцах на int64.
# *   Также следует отдельно проверить соответствие типа данных каждого столбца его содержимому.

# %%
# Выведем случайные 5 строк

df_raw.sample(5)
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 4683          2    -232.916694         37  secondary education             1
# 2239          0    -803.570754         26  secondary education             1
# 2070          1   -1197.676879         24         some college             2
# 7954          1   -1641.104402         43  secondary education             1
# 12891         1   -2403.382607         46  secondary education             1
#
#            family_status  family_status_id gender income_type  debt  \
# 4683             married                 0      M    employee     0
# 2239             married                 0      M    employee     0
# 2070   civil partnership                 1      F    employee     0
# 7954            divorced                 3      M    business     0
# 12891            married                 0      F    employee     0
#
#        total_income                              purpose
# ...

# %% [markdown]
# Следует подробнее проанализировать данные по столбцу days_employed, т.к. в нём присутствуют отрицательные значения, а также аномально высокие значения (например, по индексу 3885 количество дней работы составляет 368813 дней, а это больше 1000 лет.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Отлично!
# <br>Во время первичного анализа данных, может ещё помочь метод describe(). Он покажет разброс значений, максимум, минимум, среднее и медиану.
# </div>

# %% [markdown]
# ## Шаг 2. Выполните предобработку данных

# %% [markdown]
# 1. Найдите и изучите пропущенные значения в столбцах.
# 2. Устраните пропущенные значения: удалите или замените их.
# 3. Объясните выбранную стратегию обработки пропущенных значений.

# %% [markdown]
# ### Анализ пропущенных значений

# %% [markdown]
# Найдем пропущенные значения по столбцам

# %%
# Место для вашего кода

df.isna().mean()
# Out:
# children            0.000000
# days_employed       0.100999
# dob_years           0.000000
# education           0.000000
# education_id        0.000000
# family_status       0.000000
# family_status_id    0.000000
# gender              0.000000
# income_type         0.000000
# debt                0.000000
# total_income        0.100999
# purpose             0.000000
# dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>👍 отличный способ посмотреть долю пропусков
# </div>

# %% [markdown]
# Пропущенные значения в столбцах **days_employed** и **total_income** составляют 10% по каждому столбцу. Это существенная доля, поэтому удалять пропущенные значения мы не будем, т.к. такой шаг может негативно сказаться на точности результатов анализа.
#
# Чтобы понять, какой тип пропусков в этих столбцах, необходимо изучить, как пропуски в этих столбцах могут зависеть от других данных.
#
# Для этого изучим изучим распределение незаполненных данных в зависимости от типа дохода.

# %%
df.loc[df['days_employed'].isna()]['income_type'].value_counts()
# Out:
# income_type
# employee         1105
# business          508
# retiree           413
# civil servant     147
# entrepreneur        1
# Name: count, dtype: int64

# %%
df.loc[df['total_income'].isna()]['income_type'].value_counts()
# Out:
# income_type
# employee         1105
# business          508
# retiree           413
# civil servant     147
# entrepreneur        1
# Name: count, dtype: int64

# %% [markdown]
# Из результатов видно, как пропуски распределились в зависимости от типа дохода. Больше всего приходится на работников по найму.
#
# Посмотрим на долю пропущенных значений в столбцах **days_employed** и **total_income**, чтобы определить тип пропусков.

# %%
# Найдём долю пропущенных значений в столбце days_employed
# для каждой категории данных 'income_type':
for i in df['income_type'].unique():
    data = df.query('income_type == @i')['days_employed']
    missing_share = 1 - data.count() / len(data)
    print(f'Доля пропусков в категории "тип дохода" "{i}": {missing_share:.1%}')
# Out:
# Доля пропусков в категории "тип дохода" "employee": 9.9%
# Доля пропусков в категории "тип дохода" "retiree": 10.7%
# Доля пропусков в категории "тип дохода" "business": 10.0%
# Доля пропусков в категории "тип дохода" "civil servant": 10.1%
# Доля пропусков в категории "тип дохода" "unemployed": 0.0%
# Доля пропусков в категории "тип дохода" "entrepreneur": 50.0%
# Доля пропусков в категории "тип дохода" "student": 0.0%
# Доля пропусков в категории "тип дохода" "paternity / maternity leave": 0.0%

# %%
# Найдём долю пропущенных значений в столбце total_income
# для каждой категории данных 'income_type':
for i in df['income_type'].unique():
    data = df.query('income_type == @i')['total_income']
    missing_share = 1 - data.count() / len(data)
    print(f'Доля пропусков в категории "тип дохода" "{i}": {missing_share:.1%}')
# Out:
# Доля пропусков в категории "тип дохода" "employee": 9.9%
# Доля пропусков в категории "тип дохода" "retiree": 10.7%
# Доля пропусков в категории "тип дохода" "business": 10.0%
# Доля пропусков в категории "тип дохода" "civil servant": 10.1%
# Доля пропусков в категории "тип дохода" "unemployed": 0.0%
# Доля пропусков в категории "тип дохода" "entrepreneur": 50.0%
# Доля пропусков в категории "тип дохода" "student": 0.0%
# Доля пропусков в категории "тип дохода" "paternity / maternity leave": 0.0%

# %% [markdown]
# По результатам анализа видно, что пропуски распределились равномерно по категориям **employee, retiree, business, civil servant**
#
# Высокая доля пропущенных значений в категории **entrepreneur**, но к этой категории принадлежит только 2 клиента (проверка ниже).
#
# Можем предположить, что пропуски в столбцах **days_employed и total_income** имеют случайный характер.

# %%
df['income_type'].value_counts()
# Out:
# income_type
# employee                       11119
# business                        5085
# retiree                         3856
# civil servant                   1459
# unemployed                         2
# entrepreneur                       2
# student                            1
# paternity / maternity leave        1
# Name: count, dtype: int64

# %% [markdown]
# ### Замена пропусков, некорректных значений и дубликатов

# %% [markdown]
# Предварительно приведем в соответствие значения в колонке **education**. Данный столбец понадобится нам для замены пропусков.

# %%
df['education'] = df['education'].str.lower()

# Изучим уникальные значения в категориальных данных:
for column in ['education']:
    print(f'Уникальные значения в столбце {column}:')
    print(df[column].unique())
# Out:
# Уникальные значения в столбце education:
# ["bachelor's degree" 'secondary education' 'some college'
#  'primary education' 'graduate degree']

# %% [markdown]
# Заполним пустые значения в столбце **days_employed** с помощью метода transform медианой по агрегированным данным столбцов **gender, dob_years, income_type**, т.к. опыт работы может коррелировать с полом клиента, возрастом и типом дохода клиента.

# %%
# Используем метод .transform():
df['days_employed'] = df['days_employed'].fillna(df.groupby(['gender','dob_years','income_type'])['days_employed'].transform('median'))

# Проверим, остались ли отрицательные значения в столбце:
df.loc[df['days_employed'].isna()].count().sum()
# Out:
# 50

# %% [markdown]
# Заполним пустые значения в столбце **total_income** с помощью метода transform медианой по агрегированным данным столбцов **education, dob_years, income_type**, т.к. ежемесячный доход может коррелировать с образованием, возрастом и типом дохода клиента.

# %%
# Используем метод .transform():
df['total_income'] = df['total_income'].fillna(df.groupby(['education','dob_years','income_type'])['total_income'].transform('median'))

# Проверим, остались ли отрицательные значения в столбце:
df.loc[df['total_income'].isna()].count().sum()
# Out:
# 150

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Отличный способ для замены пропусков!
# </div>

# %% [markdown]
# Далее удалим оставшиеся пустые значения и проверим долю отфильтрованных данных

# %%
# Удалим оставшиеся пропуски:
df = df.dropna()

# Подсчитаем долю удаленных значений:
df_raw_amount = len(df_raw)
filtered_data_amount = len(df)
share = (df_raw_amount-filtered_data_amount)/df_raw_amount

print(f'Доля отфильтрованных данных: {share:.2%}')
# Out:
# Доля отфильтрованных данных: 0.07%

# %% [markdown]
# 1. Изучите уникальные значения в столбцах с уровнем образования (`education`) и полом клиента (`gender`).
# 2. Устраните неявные дубликаты и некорректные значения.

# %% [markdown]
# Уникальные значения по столбцу **education** мы обработали ранее, займемся столбцом **gender**.

# %%
# Изучим уникальные значения в категориальных данных:
for column in ['gender']:
    print(f'Уникальные значения в столбце {column}:')
    print(df[column].unique())
# Out:
# Уникальные значения в столбце gender:
# ['F' 'M' 'XNA']

# %% [markdown]
# Из результатов видно наличие выброса в виде значения XNA. Далее необходимо посчитать, сколько таких выбросов в датасете.

# %%
# Посчитаем количество значений, которые встречаются в столбце gender
df.groupby('gender').agg({'dob_years':'count'})
# Out:
#         dob_years
# gender
# F           14227
# M            7282
# XNA             1

# %% [markdown]
# Мы видим, что некорректное значение XNA встречается 1 раз. Это значение восстановить сложно, т.к. нет категорий, которые прямо указывали бы на пол клиента. Поэтому можем удалить его.

# %%
# Узнаем индекс строки с некорректным значением
df.loc[df['gender'] == 'XNA'].index

# Удалим это значение из датафрейма
df = df.drop([10701])

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Поддерживаю твоё решение! Так как мы не можем достоверно сказать, к какому полу ближе это значение, его стоит удалить или оставить как есть)
# </div>

# %% [markdown]
# 1. Проверьте наличие дубликатов. Изучите дублированные данные, если они есть, и примите решение — удалять их или оставить.

# %% [markdown]
# Посчитаем количество явных дубликатов

# %%
# Воспользуемся методом duplicated
df.duplicated().sum()
# Out:
# 71

# %% [markdown]
# Найден 71 явный дубликат. Удалим их, оставив первое вхождение дубликата

# %%
# Воспользуемся методом duplicated
df = df.drop_duplicates(keep='first')

# Проверим результат
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Датафрейм очищен от явных дубликатов

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Проверка на дубликаты выполнена!
# </div>

# %% [markdown]
# ## Шаг 3. Выбросы и аномальные значения
#
# Изучите столбцы `total_income`, `dob_years`, `chidlren` на наличие выбросов и аномальных значений, в том числе при помощи графиков. Если выбросы или аномалии будут обнаружены — обоснованно примите решение об их судьбе. Используйте подзаголовки третьего уровня (`### Подзаголовок`), чтобы создать структуру действий в рамках этого шага.

# %% [markdown]
# ### Анализ столбца days_employed

# %% [markdown]
# Сначала исправим значения в столбце days_employed:
# 1.   Превратим отрицательные значения в положительные (опыт работы не может исчисляться отрицательными значениями)
# 2.   Построим диаграмму размаха и проанализируем аномальные значения.

# %%
df['days_employed'] = df['days_employed'].abs()

# Задаем размер визуализации
plt.figure(figsize=(10, 6))

# Строим горизонтальный boxplot
sns.boxplot(x='days_employed', data=df)

# Добавим оформление графика
plt.title("Диаграмма размаха по опыту работы")
plt.xlabel("Опыт работы клиента в днях")
plt.show()

# %% [markdown]
# По результатам построения диаграммы мы видим, что в данных есть ошибочные значения в районе более 300 000. Если перевести эти данные в года, это около более 800 лет. Скорее всего произошел сбой в базе данных, и данные приняли такой вид. Разделим значения более 300 000 на 100, чтобы получить релевантные данные.

# %%
df.loc[df['days_employed'] > 300000, 'days_employed'] = df['days_employed'] / 100

# %% [markdown]
# Построим диаграмму размаха для быстрой оценки разброса данных и выявления выбросов в столбцах total_income, dob_years, chidlren

# %% [markdown]
# ### Анализ столбца total_income - диаграмма размаха

# %%
### total_income

# Задаем размер визуализации
plt.figure(figsize=(10, 6))

# Строим горизонтальный boxplot
sns.boxplot(x='total_income', data=df)

# Добавим оформление графика
plt.title("Диаграмма размаха по ежемесячному доходу клиента")
plt.xlabel("Размер ежемесячного дохода")
plt.show()

# %% [markdown]
# По графику видно, что есть глобальные выбросы с высокими значениями ежемесячного дохода, при этом доход выше 200 000 крайне редки.
#
# Ещё можно отметить, что левая граница диаграммы размаха находится в районе нуля. Возможно, такие значения характерны для пенсионеров. Проверим количество клиентов с низким ежемесячным доходом.

# %% [markdown]
# ### Анализ столбца total_income - гистограмма

# %%
# Создадим контейнер с графиком:
plt.figure(figsize=(12, 4))
sns.histplot(x='total_income', data=df, bins=range(0, 25000, 100))

# Добавим оформление графика:
plt.title('Распределение значений ежемесячного дохода ниже 25 000', fontsize=16)
plt.xlabel('Ежемесячный доход', fontsize=14)
plt.ylabel('Количество наблюдений', fontsize=14)
plt.grid()

plt.show()

# %% [markdown]
# На гистограмме распределения значений ежемесячного дохода меньше 25 000 наблюдается пик в районе 22 500. При большой доле пенсионеров в клиентской базе данные не представляются как аномальные.

# %% [markdown]
# ### Анализ столбца dob_years - диаграмма размаха

# %%
# Задаем размер визуализации
plt.figure(figsize=(10, 6))

# Строим горизонтальный boxplot
sns.boxplot(x='dob_years', data=df)

# Добавим оформление графика
plt.title("Диаграмма размаха по возрасту клиента")
plt.xlabel("Возраст клиента")
plt.show()

# %% [markdown]
# По графику видно, что есть контекстный выброс в районе нуля. Проверим количество клиентов с таким возрастом.

# %% [markdown]
# ### Анализ столбца dob_years - гистограмма

# %%
# Создадим контейнер с графиком:
plt.figure(figsize=(12, 4))
sns.histplot(x='dob_years', data=df, bins=range(0, 10, 1))

# Добавим оформление графика:
plt.title('Распределение значений возраста ниже 10-ти лет', fontsize=16)
plt.xlabel('Возраст клиента', fontsize=14)
plt.ylabel('Количество наблюдений', fontsize=14)
plt.grid()

plt.show()

# %% [markdown]
# На гистограмме распределения значений меньше 10-ти лет наблюдается пик в районе единицы. Таких наблюдений около 100.  Возможно, понадобится заменить эти значения, ориентируясь на значения в столбцах:
# - `gender` — пол клиента;
# - `income_type` — тип дохода клиента.

# %%
# Заменяем нулевые значения возраста на пустые значения:
df['dob_years'] = df['dob_years'].replace(0, np.nan)

# Используем метод .transform() для замены пустых значений по условию:
df['dob_years'] = df['dob_years'].fillna(df.groupby(['gender','income_type'])['dob_years'].transform('median'))

# Проверим долю пропусков в столбце dob_years:
df['dob_years'].isna().mean()
# Out:
# 0.0

# %% [markdown]
# ### Анализ столбца children - диаграмма размаха

# %%
# Задаем размер визуализации
plt.figure(figsize=(10, 6))

# Строим горизонтальный boxplot
sns.boxplot(x='children', data=df)

# Добавим оформление графика
plt.title("Количество детей в семье")
plt.xlabel("Количество детей")
plt.show()

# %% [markdown]
# По графику видно, что есть коллективные выбросы после значений в районе 2.
#
# Ещё можно отметить, что левая граница диаграммы размаха находится в районе меньше нуля. Возможно, это ошибочные значения. Проверим количество клиентов с количеством детей меньше нуля.
#
# Также необходимо посмотреть значение 20 (маловероятно, что есть такие плодовитые люди). Скорее всего это ошибка, нужно исправить значение на 2.

# %% [markdown]
# ### Анализ столбца children - гистограмма

# %%
# Создадим контейнер с графиком:
plt.figure(figsize=(12, 4))
sns.histplot(x='children', data=df, bins=range(-2, 0, 1))

# Добавим оформление графика:
plt.title('Распределение значений количества детей меньше нуля', fontsize=16)
plt.xlabel('Количество детей в семье', fontsize=14)
plt.ylabel('Количество наблюдений', fontsize=14)
plt.grid()

plt.show()

# %% [markdown]
# На гистограмме распределения значений меньше 0 наблюдается пик в значении -1. Таких наблюдений около 50. Очевидно, это ошибка в заполнении данных клиента. Понадобится заменить эти отрицательные значения на положительные.

# %%
# Заменим отрицательные значения в столбце children на положительные:
df['children'] = df['children'].abs()

# Проверим, остались ли отрицательные значения в столбце:
df.loc[df['children'] < 0].count().sum()
# Out:
# 0

# %% [markdown]
# Заменим значение 20 на 2

# %%
# Заменяем значения в 20 детей на пустые значения:
df['children'] = df['children'].replace(20, 2)

# Проверим, остались ли некорректные значения в столбце:
df.loc[df['children'] == 20].count().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Отличная работа с аномальными данными 👍
# </div>

# %% [markdown]
# ## Шаг 4. Добавьте в таблицу новые столбцы

# %% [markdown]
# 1. **Разделите клиентов на 5 категорий по уровню дохода:**
# - Без дохода — люди без работы и с нулевым доходом.
# - Очень низкий доход — люди, получающие ниже 14 процентиля от общего распределения дохода.
# - Низкий доход — люди, получающие между 14 и 34 процентилями от общего распределения дохода.
# - Средний доход — люди, получающие между 34 и 78 процентилями от общего распределения дохода.
# - Высокий доход — люди, получающие больше 78 процентиля от общего распределения дохода.

# %% [markdown]
# ### Анализ клиентов по уровню дохода

# %%
# Зададим название пяти категорий:
cat_names = ['Без дохода','Очень низкий доход','Низкий доход', 'Средний доход', 'Высокий доход']

# Разделим данные на 6 категорий с использованием перцентилей:
df['total_income_category'] = pd.qcut(df['total_income'], q=[0, 0.1, 0.14, 0.34, 0.78, 1], labels=cat_names)

# Изучим распределение уникальных значений в новом столбце:
df['total_income_category'].value_counts()
# Out:
# total_income_category
# Средний доход         9432
# Высокий доход         4717
# Низкий доход          4287
# Без дохода            2144
# Очень низкий доход     858
# Name: count, dtype: int64

# %% [markdown]
# Таким образом, больше всего клиентов относятся к категории с средним доходом, а меньше всего к клиентов - в категории без дохода

# %% [markdown]
# ### Анализ клиентов по возрасту

# %% [markdown]
# 1. Разделите клиентов на две категории по возрасту: до 40 лет и после. Сохраните результат в колонке `age_category`.

# %%
# Создадим функцию для категоризации клиентов по возрасту:
def age_cat(dob_years):
    """
    Функция для категоризации клиентов по возрасту:
    - До 40 лет
    - После 40 лет
    """

    if dob_years < 40:
      return 'до 40 лет'

    elif dob_years >= 40:
      return '40 лет и старше'

# Создадим новый столбец с категориями клиентов по возрасту:
df['age_category'] = df['dob_years'].apply(age_cat)

# Выведем распределение значений по этим категориям:
df['age_category'].value_counts()
# Out:
# age_category
# 40 лет и старше    12574
# до 40 лет           8864
# Name: count, dtype: int64

# %% [markdown]
# Таким образом, мы видим, что 59% клиентов в возрасте 40 лет и старше

# %% [markdown]
# ### Анализ клиентов по количеству детей (более подробная)

# %% [markdown]
# 1. Разделите клиентов на несколько категорий по количеству детей: без детей, от одного до двух, от трёх и больше. Сохраните результат в колонке `childrens_category`.

# %%
# Создадим функцию для категоризации клиентов по количеству детей:
def children_cat(children):
    """
    Функция для категоризации клиентов по количеству детей:
    - 0 - без детей
    - 1-2 - от одного до двух
    - 3 и больше - от трёх и больше
    """

    if children == 0:
      return 'без детей'

    elif children >= 1 and children <= 2:
      return 'от одного до двух'

    elif children >= 3:
      return 'от трёх и больше'

# Создадим новый столбец с категориями клиентов по количеству детей:
df['children_category'] = df['children'].apply(children_cat)

# Выведем распределение значений по этим категориям:
df['children_category'].value_counts()
# Out:
# children_category
# без детей            14079
# от одного до двух     6979
# от трёх и больше       380
# Name: count, dtype: int64

# %% [markdown]
# Таким образом, мы видим, что бОльшая часть клиентов без детей

# %% [markdown]
# ### Анализ клиентов по количеству детей (менее подробная)

# %%
# Создадим функцию для категоризации клиентов по количеству детей:
def children_short_cat(children):
    """
    Функция для категоризации клиентов по количеству детей:
    - 0 - без детей
    - 1 и больее 1-2 - с детьми
    """

    if children == 0:
      return 'без детей'

    elif children >= 1:
      return 'с детьми'

# Создадим новый столбец с категориями клиентов по количеству детей:
df['children_short_category'] = df['children'].apply(children_short_cat)

# Выведем распределение значений по этим категориям:
df['children_short_category'].value_counts()
# Out:
# children_short_category
# без детей    14079
# с детьми      7359
# Name: count, dtype: int64

# %% [markdown]
# ### Анализ клиентов по целям кредитования

# %% [markdown]
# Дополнительно разделим клиентов по целям кредитования

# %%
# Создадим функцию для категоризации клиентов целям кредитования:
def purpose_cat(purpose):
    """
    Функция для категоризации клиентов по цели кредитования:
    - Покупка недвижимости
    - Покупка машины
    - Получение образования
    - Организация свадьбы
    - Ремонт квартиры
    """
    if purpose in ['building a property','building a real estate','buy commercial real estate','buy real estate','buy residential real estate','buying property for renting out',
                     'construction of own property','property','purchase of my own house','purchase of the house','purchase of the house for my family','real estate transactions',
                     'transactions with commercial real estate','transactions with my real estate']:
      return 'to buy / build a property'

    if purpose in ['buying a second-hand car''buying my own car','car','car purchase','cars','purchase of a car','second-hand car purchase','to buy a car','to own a car']:
      return 'to buy a car'

    elif purpose in ['education','getting an education','getting higher education','profile education','supplementary education',
                     'to become educated','to get a supplementary education','university education','going to university']:
      return 'to get an education'

    elif purpose in ['having a wedding','to have a wedding','wedding ceremony']:
      return 'to have a wedding'

    elif purpose in ['housing','housing renovation','housing transactions']:
      return 'to renovate a house'

# Создадим новый столбец с категориями клиентов по цели кредитования:
df['purpose_category'] = df['purpose'].apply(purpose_cat)

# Выведем распределение значений по этим категориям:
df['purpose_category'].value_counts()
# Out:
# purpose_category
# to buy / build a property    8897
# to get an education          4011
# to buy a car                 3322
# to have a wedding            2321
# to renovate a house          1904
# Name: count, dtype: int64

# %% [markdown]
# Из результатов категоризации видно, что больше всего кредитов в нашем банке оформлеятся для целей покупки или строительства недвижимости.

# %% [markdown]
# ### Анализ клиентов по полу и наличию долгов

# %%
# Создадим функцию для категоризации клиентов по полу и наличию долгов:
def gender_debt_cat(df):
    """
    Функция для категоризации клиентов по полу и наличию долгов:
    - "M, 0" - мужчины без долгов
    - "M, 1" - мужчины с долгами
    - "F, 0" - женщины без долгов
    - "F, 1" - женщины с долгами
    """

    gender = df['gender']
    debt = df['debt']

    if gender == 'M' and debt == 0:
      return 'Мужчины без долгов'

    elif gender == 'M' and debt == 1:
      return 'Мужчины с долгами'

    elif gender == 'F' and debt == 0:
      return 'Женщины без долгов'

    elif gender == 'F' and debt == 1:
      return 'Женщины с долгами'

# Создадим новый столбец с категориями клиентов по полу и наличию долгов:
df['gender_debt_category'] = df.apply(gender_debt_cat, axis=1)

# Выведем распределение значений по этим категориям:
df['gender_debt_category'].value_counts()
# Out:
# gender_debt_category
# Женщины без долгов    13171
# Мужчины без долгов     6526
# Женщины с долгами       994
# Мужчины с долгами       747
# Name: count, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Категоризация произведена верно!
# </div>

# %% [markdown]
# ## Шаг 5. Проведите исследовательский анализ данных

# %% [markdown]
# Задайте структуру наиболее объёмной части исследования. Исследуйте факторы: `Уровень дохода`, `Образование`, `Возраст`, `Количество детей`. Отличается ли распределение между должниками и нет? Исследуйте вопрос графически. Постройте сводную таблицу по каждому фактору и покажите, как часто встречаются должники в каждой группе клиентов. Выберите подходящую визуализацию и сравните 2 группы.

# %% [markdown]
# ### Распределение клиентов по уровню дохода

# %%
# Задаем размер графика
plt.figure(figsize=(10, 6))

# Создание гистограммы с разделением клиентов по уровню дохода
sns.histplot(data=df, x='total_income', hue='debt',
             kde=True, element='step', palette='Set1')

# Заголовок и подписи осей
plt.title('Распределение уровня дохода среди должников / не должников')
plt.xlabel('Уровень дохода')
plt.ylabel('Количество клиентов')

plt.show()

# %% [markdown]
# На графике видно, что показатель уровня дохода имеет логарифмическое нормальное распределение среди клиентов, не имевших задолженность.
#
# Это связано с тем, что денежные суммы, как правило, имеют асимметричное распределение, в котором большинство значений сосредоточены в области небольших сумм, а редкие значения могут быть очень большими.
#
# Распределение среди клиентов, имевших просроченную задолженность, скорее похожа на гамма-распределение.
#
# Оба распределения право-ассиметричные.
#
# Также мы видим, что абсолютное большинство клиентов не имели просроченную задолженность.

# %% [markdown]
# ### Распределение клиентов по уровню образования

# %%
# Задаем размер графика
plt.figure(figsize=(10, 6))

# Строим гистрограмму с разделением клиентов по уровню образования
sns.histplot(data=df, x='education', hue='debt', kde=True, multiple="dodge", shrink=.8)

# Поворот подписей оси x
plt.xticks(rotation=20)

# Заголовок и подписи осей
plt.title('Распределение клиентов по уровню образования')
plt.xlabel('Уровень образования')
plt.ylabel('Количество клиентов')

plt.show()

# %% [markdown]
# Как видно на графике, распределение клиентов по уровню образования имеет скорее модальное распределение.

# %% [markdown]
# ### Распределение клиентов по возрасту

# %%
# Задаем размер графика
plt.figure(figsize=(10, 6))

# Создание гистограммы с разделением клиентов по возрасту
sns.histplot(data=df, x='dob_years', hue='debt',
             kde=True, element='step', palette='Set1')

# Заголовок и подписи осей
plt.title('Распределение клиентов по возрасту')
plt.xlabel('Возраст, лет')
plt.ylabel('Количество клиентов')

plt.show()

# %% [markdown]
# Как видно на графике, распределение клиентов по возрасту имеет скорее нормальное распределение с небольшой ассиметрией в правую сторону.

# %% [markdown]
# ### Распределение клиентов по количеству детей в семье

# %%
# Задаем размер графика
plt.figure(figsize=(10, 6))

# Создание гистограммы с разделением клиентов по количеству детей в семье
sns.histplot(data=df, x='children', hue='debt', kde=True, multiple="dodge", shrink=.8)

# Заголовок и подписи осей
plt.title('Распределение клиентов по количеству детей в семье')
plt.xlabel('Количество детей в семье')
plt.ylabel('Количество клиентов')

plt.show()

# %% [markdown]
# Как видно на графике, распределение клиентов по количеству детей в семье имеет скорее бимодальное распределение с небольшой ассиметрией в правую сторону.

# %% [markdown]
# ### Сводная таблица и столбчатая диаграмма по уровню образования и возрасту

# %%
pivot_education = df.pivot_table(
    index=['education','age_category'],
    columns='debt',
    values='total_income',
    aggfunc='count',
    fill_value=0)

# Переименуем столбцы
pivot_education_modified = pivot_education.rename(columns={
                   0: 'Клиенты без долгов',
                   1: 'Клиенты с долгами'
                   })

# Добавим расчетный столбец
pivot_education_modified['Клиенты с долгами, %'] = round(
    pivot_education_modified['Клиенты с долгами'] / (pivot_education_modified['Клиенты с долгами'] + pivot_education_modified['Клиенты без долгов']) * 100, 1
    )

# Отсортируем результат:
pivot_education_modified = pivot_education_modified.sort_values(by=['education','Клиенты с долгами, %'])

# Выведем итог
pivot_education_modified
# Out:
# debt                                 Клиенты без долгов  Клиенты с долгами  \
# education           age_category
# bachelor's degree   40 лет и старше                2469                124
#                     до 40 лет                      2499                154
# graduate degree     40 лет и старше                   4                  0
#                     до 40 лет                         2                  0
# primary education   40 лет и старше                 166                 12
#                     до 40 лет                        80                 19
# secondary education 40 лет и старше                8908                682
#                     до 40 лет                      4897                682
# some college        40 лет и старше                 190                 19
#                     до 40 лет                       482                 49
#
# debt                                 Клиенты с долгами, %
# education           age_category
# ...

# %% [markdown]
# Построим столбчатую диаграмму для наглядности

# %%
# Настраиваем размер графика
plt.figure(figsize=(10, 6))

# Настраиваем основные параметры графика
barplot = sns.barplot(
    x='education',
    y='Клиенты с долгами, %',
    data=pivot_education_modified,
    hue='age_category',
    palette='coolwarm',
    errorbar=None
    )

# Поворот подписей оси x
plt.xticks(rotation=20)

# Указываем имя графика и имена осей
barplot.set_title('Распределение должников среди клиентов в разрезе уровня образования и возраста', fontsize=12)
barplot.set_xlabel('Уровень образования', fontsize=14)
barplot.set_ylabel('Клиенты с долгами, %', fontsize=14)

# Цикл для вывода подписей ко всем барплотам
for i in barplot.containers:
  barplot.bar_label(i,)

# Выводим изображение графика
plt.show()

# %% [markdown]
# Из сводной таблицы и графика видно, среди клиентов 2-х возрастных категорий в каждой категории уровня образования больше должников среди клиентов в возрасте до 40 лет (кроме клиентов с ученой степенью).

# %% [markdown]
# ### Сводная таблица и столбчатая диаграмма по возрасту и количеству детей в семье

# %%
pivot_age = df.pivot_table(index=['age_category', 'children_category'],
               columns='debt',
               values='total_income',
               aggfunc='count',
               fill_value='-')

# Переименуем столбцы
pivot_age_modified = pivot_age.rename(columns={
                   0: 'Клиенты без долгов',
                   1: 'Клиенты с долгами'
                   })

# Добавим расчетный столбец
pivot_age_modified['Клиенты с долгами, %'] = round(
    pivot_age_modified['Клиенты с долгами'] / (pivot_age_modified['Клиенты с долгами'] + pivot_age_modified['Клиенты без долгов']) * 100, 1
    )

# Отсортируем результат:
pivot_age_modified = pivot_age_modified.sort_values(by=['age_category','Клиенты с долгами, %'])

# Выведем итог
pivot_age_modified
# Out:
# debt                               Клиенты без долгов  Клиенты с долгами  \
# age_category    children_category
# 40 лет и старше без детей                        9195                627
#                 от одного до двух                2443                201
#                 от трёх и больше                   99                  9
# до 40 лет       от трёх и больше                  250                 22
#                 без детей                        3821                436
#                 от одного до двух                3889                446
#
# debt                               Клиенты с долгами, %
# age_category    children_category
# 40 лет и старше без детей                           6.4
#                 от одного до двух                   7.6
#                 от трёх и больше                    8.3
# до 40 лет       от трёх и больше                    8.1
#                 без детей                          10.2
# ...

# %% [markdown]
# Построим столбчатую диаграмму для наглядности

# %%
# Настраиваем размер графика
plt.figure(figsize=(10, 6))

# Настраиваем основные параметры графика
barplot = sns.barplot(
    x='age_category',
    y='Клиенты с долгами, %',
    data=pivot_age_modified,
    hue='children_category',
    palette='coolwarm',
    errorbar=None
    )

# Поворот подписей оси x
plt.xticks(rotation=20)

# Указываем имя графика и имена осей
barplot.set_title('Распределение должников среди клиентов в разрезе возраста и количества детей в семье', fontsize=12)
barplot.set_xlabel('Возраст клиента', fontsize=14)
barplot.set_ylabel('Клиенты с долгами, %', fontsize=14)

# Цикл для вывода подписей ко всем барплотам
for i in barplot.containers:
  barplot.bar_label(i,)

# Выводим изображение графика
plt.show()

# %% [markdown]
# Из сводной таблицы и графика видно, что:
# *   В категории "40 лет и старше" доля должников выше у клиентов с тремя детьми и больше.
# *   В категории "до 40 лет" доля должников выше у клиентов с одним-двумя детьми и без детей.

# %% [markdown]
# ### Сводная таблица и столбчая диаграмма по уровню дохода

# %%
pivot_income = df.pivot_table(index='total_income_category',
               columns='debt',
               values='total_income',
               aggfunc='count',
               fill_value='-')

# Переименуем столбцы
pivot_income_modified = pivot_income.rename(columns={
                   0: 'Клиенты без долгов',
                   1: 'Клиенты с долгами'
                   })

# Добавим расчетный столбец
pivot_income_modified['Клиенты с долгами, %'] = round(
    pivot_income_modified['Клиенты с долгами'] / (pivot_income_modified['Клиенты с долгами'] + pivot_income_modified['Клиенты без долгов']) * 100, 1
    )

# Отсортируем результат:
pivot_income_modified = pivot_income_modified.sort_values(by='Клиенты с долгами, %')

# Выведем итог
pivot_income_modified
# Out:
# debt                   Клиенты без долгов  Клиенты с долгами  \
# total_income_category
# Высокий доход                        4388                329
# Без дохода                           1987                157
# Очень низкий доход                    786                 72
# Низкий доход                         3923                364
# Средний доход                        8613                819
#
# debt                   Клиенты с долгами, %
# total_income_category
# Высокий доход                           7.0
# Без дохода                              7.3
# Очень низкий доход                      8.4
# Низкий доход                            8.5
# Средний доход                           8.7

# %% [markdown]
# Построим столбчатую диаграмму для наглядности

# %%
# Настраиваем размер графика
plt.figure(figsize=(10, 6))

# Настраиваем основные параметры графика
barplot = sns.barplot(
    x='total_income_category',
    y='Клиенты с долгами, %',
    data=pivot_income_modified,
    errorbar=None
    )

# Поворот подписей оси x
plt.xticks(rotation=20)

# Указываем имя графика и имена осей
barplot.set_title('Распределение должников среди клиентов в разрезе уровня дохода', fontsize=12)
barplot.set_xlabel('Уровень дохода', fontsize=14)
barplot.set_ylabel('Клиенты с долгами, %', fontsize=14)

# Цикл для вывода подписей ко всем барплотам
for i in barplot.containers:
  barplot.bar_label(i,)

# Выводим изображение графика
plt.show()

# %% [markdown]
# Из сводной таблицы и графика видно, что самая высокая доля должников среди клиентов с средним уровнем дохода.

# %% [markdown]
# ### Сводная таблица и столбчатая диаграмма по целям кредитования

# %%
pivot_purpose = df.pivot_table(index='purpose_category',
               columns='debt',
               values='total_income',
               aggfunc='count',
               fill_value='-')

# Переименуем столбцы
pivot_purpose_modified = pivot_purpose.rename(columns={
                   0: 'Клиенты без долгов',
                   1: 'Клиенты с долгами'
                   })

# Добавим расчетный столбец
pivot_purpose_modified['Клиенты с долгами, %'] = round(
    pivot_purpose_modified['Клиенты с долгами'] / (pivot_purpose_modified['Клиенты с долгами'] + pivot_purpose_modified['Клиенты без долгов']) * 100, 1
    )

# Отсортируем результат:
pivot_purpose_modified = pivot_purpose_modified.sort_values(by='Клиенты с долгами, %')

# Выведем итог
pivot_purpose_modified
# Out:
# debt                       Клиенты без долгов  Клиенты с долгами  \
# purpose_category
# to renovate a house                      1775                129
# to buy / build a property                8244                653
# to have a wedding                        2135                186
# to get an education                      3641                370
# to buy a car                             3001                321
#
# debt                       Клиенты с долгами, %
# purpose_category
# to renovate a house                         6.8
# to buy / build a property                   7.3
# to have a wedding                           8.0
# to get an education                         9.2
# to buy a car                                9.7

# %% [markdown]
# Построим столбчатую диаграмму для наглядности

# %%
# Настраиваем размер графика
plt.figure(figsize=(10, 6))

# Настраиваем основные параметры графика
barplot = sns.barplot(
    x='purpose_category',
    y='Клиенты с долгами, %',
    data=pivot_purpose_modified,
    errorbar=None
    )

# Поворот подписей оси x
plt.xticks(rotation=20)

# Указываем имя графика и имена осей
barplot.set_title('Распределение должников среди клиентов в разрезе целей кредитования', fontsize=12)
barplot.set_xlabel('Цель кредита', fontsize=14)
barplot.set_ylabel('Клиенты с долгами, %', fontsize=14)

# Цикл для вывода подписей ко всем барплотам
for i in barplot.containers:
  barplot.bar_label(i,)

# Выводим изображение графика
plt.show()

# %% [markdown]
# Из сводной таблицы и графика видно, что самая высокая доля должников среди клиентов, которые оформляют кредит на покупку автомобиля и получение образования.

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>В этих заданиях тебе нужно еще найти долю должников внутри каждой группы. Для этого необходимо количество должников разделить на количество клиентов внутри группы. По полученным значениям нужно построить барплоты
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Долю должников посчитал. Барплоты построил.
# </div>

# %% [markdown]
# ### Проверка гипотез

# %% [markdown]
# ### Гипотеза №1 - клиенты с детьми / без детей

# %% [markdown]
# ***Проверьте исследовательскую гипотезу***: у клиентов с детьми более высокий уровень финансовой ответственности и, следовательно, более низкий риск просрочек по кредиту.

# %% [markdown]
# Построим сводную таблицу с категориями клиентов по наличию детей

# %%
pivot_children = df.pivot_table(
    index='children_short_category',
    columns='debt',
    values='total_income',
    aggfunc='count',
    fill_value=0)

# Переименуем столбцы
pivot_children_modified = pivot_children.rename(columns={
                   0: 'Клиенты без долгов',
                   1: 'Клиенты с долгами'
                   })

# Добавим расчетный столбец
pivot_children_modified['Клиенты с долгами, %'] = round(
    pivot_children_modified['Клиенты с долгами'] / (pivot_children_modified['Клиенты с долгами'] + pivot_children_modified['Клиенты без долгов']) * 100, 1
    )

# Отсортируем результат:
pivot_children_modified = pivot_children_modified.sort_values(by='Клиенты с долгами, %')

# Выведем итог
pivot_children_modified
# Out:
# debt                     Клиенты без долгов  Клиенты с долгами  \
# children_short_category
# без детей                             13016               1063
# с детьми                               6681                678
#
# debt                     Клиенты с долгами, %
# children_short_category
# без детей                                 7.6
# с детьми                                  9.2

# %% [markdown]
# Таким образом,
# *   В категории клиентов с детьми должники составляют 9,2%.
# *   В категории без детей должники составляют 7,6%.
#
# Гипотеза неверна.

# %% [markdown]
# ### Гипотеза №2 - одинокие / семейные мужчины

# %% [markdown]
# ***Проверьте исследовательскую гипотезу***: одинокие мужчины с низким доходом чаще оказываются должниками, чем семейные мужчины со средним доходом.

# %% [markdown]
# Для начала следует создать категорию "одинокие мужчины" и "семеные"

# %%
# Посмотрим на распределение семейного статуса и id

df_raw[['family_status', 'family_status_id']].value_counts()
# Out:
# family_status      family_status_id
# married            0                   12380
# civil partnership  1                    4177
# unmarried          4                    2813
# divorced           3                    1195
# widow / widower    2                     960
# Name: count, dtype: int64

# %% [markdown]
# Таким образом, можем распределить мужчин следующим образом, одинокие - id 2,3,4. Семейные - 0 и 1.

# %%
# Создадим функцию для категоризации клиентов по семейному положению:
def family_status_cat(family_status_id):
    """
    Функция для категоризации клиентов по семейному положению:
    - married, civil partnership - семейные
    - unmarried, divorced, widow / widower - одинокие
    """

    if family_status_id >= 0 and family_status_id < 2:
      return 'семейный'

    elif family_status_id >= 2 and family_status_id <= 4:
      return 'одинокий'

# Создадим новый столбец с категориями клиентов по семейному положению:
df['family_status_category'] = df['family_status_id'].apply(family_status_cat)

# Выведем распределение значений по этим категориям:
df['family_status_category'].value_counts()
# Out:
# family_status_category
# семейный    16477
# одинокий     4961
# Name: count, dtype: int64

# %% [markdown]
# Построим сводную таблицу с категоризацией клиентов по полу, семейному статусу и уровню дохода

# %%
gender_male = df.loc[df['gender'] == 'M']

pivot_men_status = gender_male.pivot_table(
    index=['family_status_category', 'total_income_category'],
    columns=['gender_debt_category'],
    values='total_income',
    aggfunc='count',
    fill_value='-')

# Переименуем столбцы
pivot_men_status_modified = pivot_men_status.rename(columns={
                   0: 'Мужчины без долгов',
                   1: 'Мужчины с долгами'
                   })

# Добавим расчетный столбец
pivot_men_status_modified['Мужчины с долгами, %'] = round(
    pivot_men_status_modified['Мужчины с долгами'] / (pivot_men_status_modified['Мужчины без долгов'] + pivot_men_status_modified['Мужчины с долгами']) * 100, 1
    )

# Отсортируем результат:
pivot_men_status_modified = pivot_men_status_modified.sort_values(by='Мужчины с долгами, %')

# Выведем итог
pivot_men_status_modified
# Out:
# gender_debt_category                          Мужчины без долгов  \
# family_status_category total_income_category
# семейный               high_income                          1680
#                        without_income                        255
#                        low_income                            793
#                        average_income                       2480
#                        very_low_income                       115
# одинокий               high_income                           329
#                        average_income                        557
#                        very_low_income                        32
#                        without_income                         74
#                        low_income                            211
#
# gender_debt_category                          Мужчины с долгами  \
# family_status_category total_income_category
# семейный               high_income                          130
# ...

# %% [markdown]
# Таким образом,
# *   В категории семейных мужчин с средним доходом должники составляют 10,5%.
# *   В категории одиноких мужчин с низким доходом должники составляют 15,9%.
#
# Гипотеза верна.

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Для проверки этих гипотез тебе тоже нужно найти именно долю должников внутри каждой группы:
#
#     количество клиентов без детей и с долгом / (количество клиентов без детей и с долгом + количество клиентов без детей и без долга)
#
# <br>Ты проводишь нужные расчеты, но в комментариях. Давай лучше построим сводные таблицы используя метод pivot_table.
# </div>

# %% [markdown]
# Сводные таблицы построил. Как раз это и хотел в первой версии сделать, не додумал. ;)

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Рассчитывать корреляцию Пирсона в данном случае нельзя, так как переменная debt - категориальная.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Удалил.
# </div>

# %% [markdown]
# ## Шаг 6. Напишите общий вывод

# %% [markdown]
# Для общего вывода построим сводную таблицу

# %%
pivot_men_status = df.pivot_table(
    index=['family_status_category', 'total_income_category', 'age_category'],
    columns='gender_debt_category',
    values='total_income',
    aggfunc='count',
    fill_value=0)

# Переименование столбцов
pivot_men_status_modified = pivot_men_status.rename(columns={
    'F': 'Женщины',
    'M': 'Мужчины',
    0: 'без долгов',
    1: 'с долгами'
    })

# Добавим расчетный столбец для женщин
pivot_men_status_modified['Женщины с долгами, %'] = round(
    pivot_men_status_modified['Женщины с долгами'] / (pivot_men_status_modified['Женщины без долгов'] + pivot_men_status_modified['Женщины с долгами']) * 100, 1
   )

# Добавим расчетный столбец для мужчин
pivot_men_status_modified['Мужчины с долгами, %'] = round(
    pivot_men_status_modified['Мужчины с долгами'] / (pivot_men_status_modified['Мужчины без долгов'] + pivot_men_status_modified['Мужчины с долгами']) * 100, 1
   )

# Выводим результат
pivot_men_status_modified
# Out:
# gender_debt_category                                          Женщины без долгов  \
# family_status_category total_income_category age_category
# одинокий               Без дохода            40 лет и старше                 303
#                                              до 40 лет                        89
#                        Очень низкий доход    40 лет и старше                 107
#                                              до 40 лет                        56
#                        Низкий доход          40 лет и старше                 528
#                                              до 40 лет                       221
#                        Средний доход         40 лет и старше                 943
#                                              до 40 лет                       472
#                        Высокий доход         40 лет и старше                 419
#                                              до 40 лет                       198
# ...

# %% [markdown]
# Таким образом, в категории
#
# *   одиноких мужчин со средним доходом доля должников значительно выше у клиентов "до 40 лет" по сравнению с клиентами "40 лет и старше"
# *   семейных мужчин с очень низким доходом доля должников значительно выше у клиентов "40 лет и старше" по сравнению с клиентами "до 40 лет"
#
# *   одиноких женщин без дохода доля должников значительно выше у клиентов "до 40 лет" по сравнению с клиентами "40 лет и старше"
# *   семейных женщин любых уровней дохода доля должников выше у клиентов "до 40 лет" по сравнению с клиентами "40 лет и старше"
#
# **Лучшие среди одиноких мужчин**
# * со средним уровнем дохода "40 лет и старше"
#
# **Лучшие среди одиноких женщин**
# * без дохода "40 лет и старше"
# * с высоким доходом
#
# **Лучшие среди семейных мужчин**
# * c высоким доходом
# * с очень низким доходом "до 40 лет"
#
# **Лучшие среди семейных женщин**
# * всех уровней дохода "40 лет и старше"

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Тут ещё можно было бы объеденить все категории кроме образования и сравнить должников в таком разрезе
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Добавил, только не учел ещё цель кредита, иначе совсем большая таблица получилась бы.
# </div>

# %% [markdown]
# ## *Шаг 7. Проведите дополнительное исследование

# %% [markdown]
# (Необязательное задание) Исследуйте причины оформления кредита. Правда ли, что люди, которые брали кредит на образование, реже всего оказывались должниками?

# %%
# Изучите уникальные значения в поле purpose

# %%
# Разделите клиентов на 2 группы
def find_education_purpose(purpose):
  pass

# %%
# Исследуйте полученные группы по доле не вернувших кредит

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Итоговый комментарий ревьюера v1:</b>
# <br>Необходимо поправить:
# <br>- найти долю должников
# <br>- удалить расчет корреляции
#
# <br>После всех внесённых правок не забудь поправить выводы там, где это необходимо
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Исправил. Спасибо.
# </div>
